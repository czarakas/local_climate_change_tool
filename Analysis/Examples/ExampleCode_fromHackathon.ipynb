# %% [markdown]
# # Hello World!
#
# Here's an example notebook with some documentation on how to access CMIP data.

# %%
### Information with Directory Structure
dir_util = '/home/jovyan/local-climate-data-tool/Analysis/'
dir_catalog = '/home/jovyan/local-climate-data-tool/Data/catalogs/'

# %%
# %matplotlib inline

import xarray as xr
import intake
import sys

# util.py is in the local directory
# it contains code that is common across project notebooks
# or routines that are too extensive and might otherwise clutter
# the notebook design
sys.path.insert(0, dir_util)
import util
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/intake/source/discovery.py:136: FutureWarning: The drivers ['stac-catalog', 'stac-collection', 'stac-item'] do not specify entry_points and were only discovered via a package scan. This may break in a future release of intake. The packages should be updated.
#   FutureWarning)

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# ## Demonstrate how to use `intake-esm`
# [Intake-esm](https://intake-esm.readthedocs.io) is a data cataloging utility that facilitates access to CMIP data. It's pretty awesome.
#
# An `intake-esm` collection object establishes a link to a database that contains file locations and associated metadata (i.e. which experiement, model, etc. thet come from).
#
# ### Opening a collection
# First step is to open a collection by pointing to the collection definition file, which is a JSON file that conforms to the [ESM Collection Specification](https://github.com/NCAR/esm-collection-spec).
#
# The collection JSON files are stored locally in this repository for purposes of reproducibility---and because Cheyenne compute nodes don't have Internet access.
#
# The primary source for these files is the [intake-esm-datastore](https://github.com/NCAR/intake-esm-datastore) repository. Any changes made to these files should be pulled from that repo. For instance, the Pangeo cloud collection is available [here](https://raw.githubusercontent.com/NCAR/intake-esm-datastore/master/catalogs/pangeo-cmip6.json).

# %%
if util.is_ncar_host():
    col = intake.open_esm_datastore(dir_catalog+"glade-cmip6.json")
else:
    col = intake.open_esm_datastore(dir_catalog+"pangeo-cmip6.json")
col
# Out:
# pangeo-cmip6-ESM Collection with 28314 entries:
# 	> 10 activity_id(s)
#
# 	> 23 institution_id(s)
#
# 	> 48 source_id(s)
#
# 	> 29 experiment_id(s)
#
# 	> 86 member_id(s)
#
# 	> 24 table_id(s)
#
# 	> 190 variable_id(s)
#
# 	> 7 grid_label(s)
#
# 	> 28314 zstore(s)
#
# 	> 59 dcpp_init_year(s)

# %% [markdown]
# `intake-esm` is build on top of [pandas](https://pandas.pydata.org/pandas-docs/stable). It is possible to view the `pandas.DataFrame` as follows.

# %%
col.df.head()
# Out:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 1  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 2  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 3  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 4  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
#
#   variable_id grid_label                                             zstore  \
# 0          pr         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 1        prsn         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 2         tas         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 3      tasmax         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 4      tasmin         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
#
#    dcpp_init_year
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %% [markdown]
# It is possible to interact with the `DataFrame`; for instance, we can see what the "attributes" of the datasets are by printing the columns.

# %%
col.df.columns
# Out:
# Index(['activity_id', 'institution_id', 'source_id', 'experiment_id',
#        'member_id', 'table_id', 'variable_id', 'grid_label', 'zstore',
#        'dcpp_init_year'],
#       dtype='object')

# %% [markdown]
# ### Search and discovery
#
# #### Finding unique entries
# Let's query the data to see what models ("source_id"), experiments ("experiment_id") and temporal frequencies ("table_id") are available.

# %%
import pprint 
uni_dict = col.unique(['source_id', 'experiment_id', 'table_id'])
pprint.pprint(uni_dict, compact=True)
# Out:
# {'experiment_id': {'count': 29,
#                    'values': ['ssp370', 'esm-ssp585', '1pctCO2-bgc', 'hist-bgc',
#                               '1pctCO2', 'abrupt-4xCO2', 'historical',
#                               'piControl', 'amip', 'esm-hist', 'esm-piControl',
#                               'hist-GHG', 'hist-aer', 'hist-nat', 'dcppA-assim',
#                               'dcppA-hindcast', 'dcppC-hindcast-noAgung',
#                               'dcppC-hindcast-noElChichon',
#                               'dcppC-hindcast-noPinatubo', 'highresSST-present',
#                               'control-1950', 'hist-1950', 'deforest-globe',
#                               'esm-ssp585-ssp126Lu', 'omip1', 'lgm', 'ssp126',
#                               'ssp245', 'ssp585']},
#  'source_id': {'count': 48,
#                'values': ['BCC-ESM1', 'BCC-CSM2-MR', 'CanESM5', 'CNRM-ESM2-1',
#                           'UKESM1-0-LL', 'GISS-E2-1-G', 'CESM2', 'GFDL-ESM4',
#                           'AWI-CM-1-1-MR', 'CAMS-CSM1-0', 'FGOALS-f3-L',
#                           'FGOALS-g3', 'CNRM-CM6-1', 'E3SM-1-0', 'EC-Earth3-LR',
#                           'EC-Earth3-Veg', 'EC-Earth3', 'FIO-ESM-2-0',
#                           'IPSL-CM6A-LR', 'MIROC-ES2L', 'MIROC6',
#                           'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM', 'MRI-ESM2-0',
#                           'GISS-E2-1-G-CC', 'GISS-E2-1-H', 'CESM2-WACCM',
#                           'NorCPM1', 'NorESM2-LM', 'GFDL-CM4', 'NESM3',
#                           'SAM0-UNICON', 'MCM-UA-1-0', 'CMCC-CM2-HR4',
#                           'CMCC-CM2-VHR4', 'CNRM-CM6-1-HR', 'ECMWF-IFS-HR',
#                           'ECMWF-IFS-LR', 'IPSL-CM6A-ATM-HR', 'NICAM16-7S',
#                           'NICAM16-8S', 'NICAM16-9S', 'HadGEM3-GC31-HM',
#                           'HadGEM3-GC31-LM', 'MRI-AGCM3-2-H', 'MRI-AGCM3-2-S',
#                           'GFDL-CM4C192', 'MPI-ESM1-2-HR']},
#  'table_id': {'count': 24,
#               'values': ['Amon', 'Lmon', 'Oyr', 'Omon', 'SImon', 'day', '3hr',
#                          '6hrLev', 'LImon', 'Aclim', 'Ofx', 'fx', 'CFday',
#                          'Emon', '6hrPlev', 'Oclim', 'SIclim', 'Eclim', 'Odec',
#                          'AERmon', 'ImonGre', '6hrPlevPt', 'CF3hr', 'E3hr']}}

# %% [markdown]
# #### Searching for specific datasets
#
# Let's find all the dissolved oxygen data at annual frequency from the ocean for the `historical` and `ssp585` experiments.

# %%
cat = col.search(experiment_id=['historical', 'ssp585'], table_id='Oyr', variable_id='o2', grid_label='gn')
cat.df
# Out:
#        activity_id institution_id      source_id experiment_id  member_id  \
# 1532          CMIP          CCCma        CanESM5    historical  r10i1p1f1
# 1601          CMIP          CCCma        CanESM5    historical  r10i1p2f1
# 1671          CMIP          CCCma        CanESM5    historical  r11i1p1f1
# 1767          CMIP          CCCma        CanESM5    historical  r12i1p1f1
# 1863          CMIP          CCCma        CanESM5    historical  r13i1p1f1
# 1960          CMIP          CCCma        CanESM5    historical  r14i1p1f1
# 2056          CMIP          CCCma        CanESM5    historical  r15i1p1f1
# 2152          CMIP          CCCma        CanESM5    historical  r16i1p1f1
# 2248          CMIP          CCCma        CanESM5    historical  r17i1p1f1
# 2345          CMIP          CCCma        CanESM5    historical  r18i1p1f1
# 2442          CMIP          CCCma        CanESM5    historical  r19i1p1f1
# 2538          CMIP          CCCma        CanESM5    historical   r1i1p1f1
# 2606          CMIP          CCCma        CanESM5    historical   r1i1p2f1
# 2677          CMIP          CCCma        CanESM5    historical  r20i1p1f1
# 2773          CMIP          CCCma        CanESM5    historical  r21i1p1f1
# 2870          CMIP          CCCma        CanESM5    historical  r22i1p1f1
# 2968          CMIP          CCCma        CanESM5    historical  r23i1p1f1
# 3064          CMIP          CCCma        CanESM5    historical  r24i1p1f1
# 3161          CMIP          CCCma        CanESM5    historical  r25i1p1f1
# 3257          CMIP          CCCma        CanESM5    historical   r2i1p1f1
# 3327          CMIP          CCCma        CanESM5    historical   r2i1p2f1
# 3397          CMIP          CCCma        CanESM5    historical   r3i1p1f1
# 3465          CMIP          CCCma        CanESM5    historical   r3i1p2f1
# 3536          CMIP          CCCma        CanESM5    historical   r4i1p1f1
# 3604          CMIP          CCCma        CanESM5    historical   r4i1p2f1
# 3674          CMIP          CCCma        CanESM5    historical   r5i1p1f1
# 3731          CMIP          CCCma        CanESM5    historical   r5i1p2f1
# 3802          CMIP          CCCma        CanESM5    historical   r6i1p1f1
# 3870          CMIP          CCCma        CanESM5    historical   r6i1p2f1
# 3941          CMIP          CCCma        CanESM5    historical   r7i1p1f1
# ...            ...            ...            ...           ...        ...
# 8957          CMIP           IPSL   IPSL-CM6A-LR    historical   r6i1p1f1
# 9037          CMIP           IPSL   IPSL-CM6A-LR    historical   r7i1p1f1
# 9117          CMIP           IPSL   IPSL-CM6A-LR    historical   r8i1p1f1
# 9197          CMIP           IPSL   IPSL-CM6A-LR    historical   r9i1p1f1
# 9432          CMIP          MIROC     MIROC-ES2L    historical   r1i1p1f2
# 9500          CMIP          MIROC     MIROC-ES2L    historical   r2i1p1f2
# 9568          CMIP          MIROC     MIROC-ES2L    historical   r3i1p1f2
# 22250  ScenarioMIP          CCCma        CanESM5        ssp585  r10i1p1f1
# 22326  ScenarioMIP          CCCma        CanESM5        ssp585  r10i1p2f1
# 22750  ScenarioMIP          CCCma        CanESM5        ssp585   r1i1p1f1
# 22813  ScenarioMIP          CCCma        CanESM5        ssp585   r1i1p2f1
# 23116  ScenarioMIP          CCCma        CanESM5        ssp585   r2i1p1f1
# 23178  ScenarioMIP          CCCma        CanESM5        ssp585   r2i1p2f1
# 23241  ScenarioMIP          CCCma        CanESM5        ssp585   r3i1p1f1
# 23303  ScenarioMIP          CCCma        CanESM5        ssp585   r3i1p2f1
# 23366  ScenarioMIP          CCCma        CanESM5        ssp585   r4i1p1f1
# 23428  ScenarioMIP          CCCma        CanESM5        ssp585   r4i1p2f1
# 23492  ScenarioMIP          CCCma        CanESM5        ssp585   r5i1p1f1
# 23555  ScenarioMIP          CCCma        CanESM5        ssp585   r5i1p2f1
# 23619  ScenarioMIP          CCCma        CanESM5        ssp585   r6i1p1f1
# 23681  ScenarioMIP          CCCma        CanESM5        ssp585   r6i1p2f1
# 23745  ScenarioMIP          CCCma        CanESM5        ssp585   r7i1p1f1
# 23807  ScenarioMIP          CCCma        CanESM5        ssp585   r7i1p2f1
# 23870  ScenarioMIP          CCCma        CanESM5        ssp585   r8i1p1f1
# 23933  ScenarioMIP          CCCma        CanESM5        ssp585   r8i1p2f1
# 23997  ScenarioMIP          CCCma        CanESM5        ssp585   r9i1p1f1
# 24060  ScenarioMIP          CCCma        CanESM5        ssp585   r9i1p2f1
# 25639  ScenarioMIP           DKRZ  MPI-ESM1-2-HR        ssp585   r1i1p1f1
# 26101  ScenarioMIP           IPSL   IPSL-CM6A-LR        ssp585   r1i1p1f1
# 26278  ScenarioMIP          MIROC     MIROC-ES2L        ssp585   r1i1p1f2
#
#       table_id variable_id grid_label  \
# 1532       Oyr          o2         gn
# 1601       Oyr          o2         gn
# 1671       Oyr          o2         gn
# 1767       Oyr          o2         gn
# 1863       Oyr          o2         gn
# 1960       Oyr          o2         gn
# 2056       Oyr          o2         gn
# 2152       Oyr          o2         gn
# 2248       Oyr          o2         gn
# 2345       Oyr          o2         gn
# 2442       Oyr          o2         gn
# 2538       Oyr          o2         gn
# 2606       Oyr          o2         gn
# 2677       Oyr          o2         gn
# 2773       Oyr          o2         gn
# 2870       Oyr          o2         gn
# 2968       Oyr          o2         gn
# 3064       Oyr          o2         gn
# 3161       Oyr          o2         gn
# 3257       Oyr          o2         gn
# 3327       Oyr          o2         gn
# 3397       Oyr          o2         gn
# 3465       Oyr          o2         gn
# 3536       Oyr          o2         gn
# 3604       Oyr          o2         gn
# 3674       Oyr          o2         gn
# 3731       Oyr          o2         gn
# 3802       Oyr          o2         gn
# 3870       Oyr          o2         gn
# 3941       Oyr          o2         gn
# ...        ...         ...        ...
# 8957       Oyr          o2         gn
# 9037       Oyr          o2         gn
# 9117       Oyr          o2         gn
# 9197       Oyr          o2         gn
# 9432       Oyr          o2         gn
# 9500       Oyr          o2         gn
# 9568       Oyr          o2         gn
# 22250      Oyr          o2         gn
# 22326      Oyr          o2         gn
# 22750      Oyr          o2         gn
# 22813      Oyr          o2         gn
# 23116      Oyr          o2         gn
# 23178      Oyr          o2         gn
# 23241      Oyr          o2         gn
# 23303      Oyr          o2         gn
# 23366      Oyr          o2         gn
# 23428      Oyr          o2         gn
# 23492      Oyr          o2         gn
# 23555      Oyr          o2         gn
# 23619      Oyr          o2         gn
# 23681      Oyr          o2         gn
# 23745      Oyr          o2         gn
# 23807      Oyr          o2         gn
# 23870      Oyr          o2         gn
# 23933      Oyr          o2         gn
# 23997      Oyr          o2         gn
# 24060      Oyr          o2         gn
# 25639      Oyr          o2         gn
# 26101      Oyr          o2         gn
# 26278      Oyr          o2         gn
#
#                                                   zstore  dcpp_init_year
# 1532   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1601   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1671   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1767   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1863   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1960   gs://cmip6/CMIP/CCCma/CanESM5/historical/r14i1...             NaN
# 2056   gs://cmip6/CMIP/CCCma/CanESM5/historical/r15i1...             NaN
# 2152   gs://cmip6/CMIP/CCCma/CanESM5/historical/r16i1...             NaN
# 2248   gs://cmip6/CMIP/CCCma/CanESM5/historical/r17i1...             NaN
# 2345   gs://cmip6/CMIP/CCCma/CanESM5/historical/r18i1...             NaN
# 2442   gs://cmip6/CMIP/CCCma/CanESM5/historical/r19i1...             NaN
# 2538   gs://cmip6/CMIP/CCCma/CanESM5/historical/r1i1p...             NaN
# 2606   gs://cmip6/CMIP/CCCma/CanESM5/historical/r1i1p...             NaN
# 2677   gs://cmip6/CMIP/CCCma/CanESM5/historical/r20i1...             NaN
# 2773   gs://cmip6/CMIP/CCCma/CanESM5/historical/r21i1...             NaN
# 2870   gs://cmip6/CMIP/CCCma/CanESM5/historical/r22i1...             NaN
# 2968   gs://cmip6/CMIP/CCCma/CanESM5/historical/r23i1...             NaN
# 3064   gs://cmip6/CMIP/CCCma/CanESM5/historical/r24i1...             NaN
# 3161   gs://cmip6/CMIP/CCCma/CanESM5/historical/r25i1...             NaN
# 3257   gs://cmip6/CMIP/CCCma/CanESM5/historical/r2i1p...             NaN
# 3327   gs://cmip6/CMIP/CCCma/CanESM5/historical/r2i1p...             NaN
# 3397   gs://cmip6/CMIP/CCCma/CanESM5/historical/r3i1p...             NaN
# 3465   gs://cmip6/CMIP/CCCma/CanESM5/historical/r3i1p...             NaN
# 3536   gs://cmip6/CMIP/CCCma/CanESM5/historical/r4i1p...             NaN
# 3604   gs://cmip6/CMIP/CCCma/CanESM5/historical/r4i1p...             NaN
# 3674   gs://cmip6/CMIP/CCCma/CanESM5/historical/r5i1p...             NaN
# 3731   gs://cmip6/CMIP/CCCma/CanESM5/historical/r5i1p...             NaN
# 3802   gs://cmip6/CMIP/CCCma/CanESM5/historical/r6i1p...             NaN
# 3870   gs://cmip6/CMIP/CCCma/CanESM5/historical/r6i1p...             NaN
# 3941   gs://cmip6/CMIP/CCCma/CanESM5/historical/r7i1p...             NaN
# ...                                                  ...             ...
# 8957   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 9037   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 9117   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 9197   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 9432   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r1...             NaN
# 9500   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r2...             NaN
# 9568   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r3...             NaN
# 22250  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 22326  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 22750  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 22813  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 23116  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r2...             NaN
# 23178  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r2...             NaN
# 23241  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r3...             NaN
# 23303  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r3...             NaN
# 23366  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r4...             NaN
# 23428  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r4...             NaN
# 23492  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r5...             NaN
# 23555  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r5...             NaN
# 23619  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r6...             NaN
# 23681  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r6...             NaN
# 23745  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23807  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23870  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23933  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23997  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24060  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 25639  gs://cmip6/ScenarioMIP/DKRZ/MPI-ESM1-2-HR/ssp5...             NaN
# 26101  gs://cmip6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp58...             NaN
# 26278  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
#
# [93 rows x 10 columns]

# %% [markdown]
# It might be desirable to get more specific. For instance, we may want to select only the models that have *both* `historical` and `ssp585` data. We coud do this as follows.

# %%
models = set(uni_dict['source_id']['values']) # all the models

for experiment_id in ['historical', 'ssp585']:
    query = dict(experiment_id=experiment_id, table_id='Oyr', 
                 variable_id='o2', grid_label='gn')  
    cat = col.search(**query)
    models = models.intersection({model for model in cat.df.source_id.unique().tolist()})

# ensure the CESM2 models are not included (oxygen was erroneously submitted to the archive)
models = models - {'CESM2-WACCM', 'CESM2'}

models = list(models)
models
# Out:
# ['CanESM5', 'IPSL-CM6A-LR', 'MIROC-ES2L']

# %%
cat = col.search(experiment_id=['historical', 'ssp585'], table_id='Oyr', 
                 variable_id='o2', grid_label='gn', source_id=models)
cat.df
# Out:
#        activity_id institution_id     source_id experiment_id  member_id  \
# 1532          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1601          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1671          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1767          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1863          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1960          CMIP          CCCma       CanESM5    historical  r14i1p1f1
# 2056          CMIP          CCCma       CanESM5    historical  r15i1p1f1
# 2152          CMIP          CCCma       CanESM5    historical  r16i1p1f1
# 2248          CMIP          CCCma       CanESM5    historical  r17i1p1f1
# 2345          CMIP          CCCma       CanESM5    historical  r18i1p1f1
# 2442          CMIP          CCCma       CanESM5    historical  r19i1p1f1
# 2538          CMIP          CCCma       CanESM5    historical   r1i1p1f1
# 2606          CMIP          CCCma       CanESM5    historical   r1i1p2f1
# 2677          CMIP          CCCma       CanESM5    historical  r20i1p1f1
# 2773          CMIP          CCCma       CanESM5    historical  r21i1p1f1
# 2870          CMIP          CCCma       CanESM5    historical  r22i1p1f1
# 2968          CMIP          CCCma       CanESM5    historical  r23i1p1f1
# 3064          CMIP          CCCma       CanESM5    historical  r24i1p1f1
# 3161          CMIP          CCCma       CanESM5    historical  r25i1p1f1
# 3257          CMIP          CCCma       CanESM5    historical   r2i1p1f1
# 3327          CMIP          CCCma       CanESM5    historical   r2i1p2f1
# 3397          CMIP          CCCma       CanESM5    historical   r3i1p1f1
# 3465          CMIP          CCCma       CanESM5    historical   r3i1p2f1
# 3536          CMIP          CCCma       CanESM5    historical   r4i1p1f1
# 3604          CMIP          CCCma       CanESM5    historical   r4i1p2f1
# 3674          CMIP          CCCma       CanESM5    historical   r5i1p1f1
# 3731          CMIP          CCCma       CanESM5    historical   r5i1p2f1
# 3802          CMIP          CCCma       CanESM5    historical   r6i1p1f1
# 3870          CMIP          CCCma       CanESM5    historical   r6i1p2f1
# 3941          CMIP          CCCma       CanESM5    historical   r7i1p1f1
# ...            ...            ...           ...           ...        ...
# 8877          CMIP           IPSL  IPSL-CM6A-LR    historical   r5i1p1f1
# 8957          CMIP           IPSL  IPSL-CM6A-LR    historical   r6i1p1f1
# 9037          CMIP           IPSL  IPSL-CM6A-LR    historical   r7i1p1f1
# 9117          CMIP           IPSL  IPSL-CM6A-LR    historical   r8i1p1f1
# 9197          CMIP           IPSL  IPSL-CM6A-LR    historical   r9i1p1f1
# 9432          CMIP          MIROC    MIROC-ES2L    historical   r1i1p1f2
# 9500          CMIP          MIROC    MIROC-ES2L    historical   r2i1p1f2
# 9568          CMIP          MIROC    MIROC-ES2L    historical   r3i1p1f2
# 22250  ScenarioMIP          CCCma       CanESM5        ssp585  r10i1p1f1
# 22326  ScenarioMIP          CCCma       CanESM5        ssp585  r10i1p2f1
# 22750  ScenarioMIP          CCCma       CanESM5        ssp585   r1i1p1f1
# 22813  ScenarioMIP          CCCma       CanESM5        ssp585   r1i1p2f1
# 23116  ScenarioMIP          CCCma       CanESM5        ssp585   r2i1p1f1
# 23178  ScenarioMIP          CCCma       CanESM5        ssp585   r2i1p2f1
# 23241  ScenarioMIP          CCCma       CanESM5        ssp585   r3i1p1f1
# 23303  ScenarioMIP          CCCma       CanESM5        ssp585   r3i1p2f1
# 23366  ScenarioMIP          CCCma       CanESM5        ssp585   r4i1p1f1
# 23428  ScenarioMIP          CCCma       CanESM5        ssp585   r4i1p2f1
# 23492  ScenarioMIP          CCCma       CanESM5        ssp585   r5i1p1f1
# 23555  ScenarioMIP          CCCma       CanESM5        ssp585   r5i1p2f1
# 23619  ScenarioMIP          CCCma       CanESM5        ssp585   r6i1p1f1
# 23681  ScenarioMIP          CCCma       CanESM5        ssp585   r6i1p2f1
# 23745  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23807  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23870  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23933  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23997  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 24060  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 26101  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585   r1i1p1f1
# 26278  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
#
#       table_id variable_id grid_label  \
# 1532       Oyr          o2         gn
# 1601       Oyr          o2         gn
# 1671       Oyr          o2         gn
# 1767       Oyr          o2         gn
# 1863       Oyr          o2         gn
# 1960       Oyr          o2         gn
# 2056       Oyr          o2         gn
# 2152       Oyr          o2         gn
# 2248       Oyr          o2         gn
# 2345       Oyr          o2         gn
# 2442       Oyr          o2         gn
# 2538       Oyr          o2         gn
# 2606       Oyr          o2         gn
# 2677       Oyr          o2         gn
# 2773       Oyr          o2         gn
# 2870       Oyr          o2         gn
# 2968       Oyr          o2         gn
# 3064       Oyr          o2         gn
# 3161       Oyr          o2         gn
# 3257       Oyr          o2         gn
# 3327       Oyr          o2         gn
# 3397       Oyr          o2         gn
# 3465       Oyr          o2         gn
# 3536       Oyr          o2         gn
# 3604       Oyr          o2         gn
# 3674       Oyr          o2         gn
# 3731       Oyr          o2         gn
# 3802       Oyr          o2         gn
# 3870       Oyr          o2         gn
# 3941       Oyr          o2         gn
# ...        ...         ...        ...
# 8877       Oyr          o2         gn
# 8957       Oyr          o2         gn
# 9037       Oyr          o2         gn
# 9117       Oyr          o2         gn
# 9197       Oyr          o2         gn
# 9432       Oyr          o2         gn
# 9500       Oyr          o2         gn
# 9568       Oyr          o2         gn
# 22250      Oyr          o2         gn
# 22326      Oyr          o2         gn
# 22750      Oyr          o2         gn
# 22813      Oyr          o2         gn
# 23116      Oyr          o2         gn
# 23178      Oyr          o2         gn
# 23241      Oyr          o2         gn
# 23303      Oyr          o2         gn
# 23366      Oyr          o2         gn
# 23428      Oyr          o2         gn
# 23492      Oyr          o2         gn
# 23555      Oyr          o2         gn
# 23619      Oyr          o2         gn
# 23681      Oyr          o2         gn
# 23745      Oyr          o2         gn
# 23807      Oyr          o2         gn
# 23870      Oyr          o2         gn
# 23933      Oyr          o2         gn
# 23997      Oyr          o2         gn
# 24060      Oyr          o2         gn
# 26101      Oyr          o2         gn
# 26278      Oyr          o2         gn
#
#                                                   zstore  dcpp_init_year
# 1532   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1601   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1671   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1767   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1863   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1960   gs://cmip6/CMIP/CCCma/CanESM5/historical/r14i1...             NaN
# 2056   gs://cmip6/CMIP/CCCma/CanESM5/historical/r15i1...             NaN
# 2152   gs://cmip6/CMIP/CCCma/CanESM5/historical/r16i1...             NaN
# 2248   gs://cmip6/CMIP/CCCma/CanESM5/historical/r17i1...             NaN
# 2345   gs://cmip6/CMIP/CCCma/CanESM5/historical/r18i1...             NaN
# 2442   gs://cmip6/CMIP/CCCma/CanESM5/historical/r19i1...             NaN
# 2538   gs://cmip6/CMIP/CCCma/CanESM5/historical/r1i1p...             NaN
# 2606   gs://cmip6/CMIP/CCCma/CanESM5/historical/r1i1p...             NaN
# 2677   gs://cmip6/CMIP/CCCma/CanESM5/historical/r20i1...             NaN
# 2773   gs://cmip6/CMIP/CCCma/CanESM5/historical/r21i1...             NaN
# 2870   gs://cmip6/CMIP/CCCma/CanESM5/historical/r22i1...             NaN
# 2968   gs://cmip6/CMIP/CCCma/CanESM5/historical/r23i1...             NaN
# 3064   gs://cmip6/CMIP/CCCma/CanESM5/historical/r24i1...             NaN
# 3161   gs://cmip6/CMIP/CCCma/CanESM5/historical/r25i1...             NaN
# 3257   gs://cmip6/CMIP/CCCma/CanESM5/historical/r2i1p...             NaN
# 3327   gs://cmip6/CMIP/CCCma/CanESM5/historical/r2i1p...             NaN
# 3397   gs://cmip6/CMIP/CCCma/CanESM5/historical/r3i1p...             NaN
# 3465   gs://cmip6/CMIP/CCCma/CanESM5/historical/r3i1p...             NaN
# 3536   gs://cmip6/CMIP/CCCma/CanESM5/historical/r4i1p...             NaN
# 3604   gs://cmip6/CMIP/CCCma/CanESM5/historical/r4i1p...             NaN
# 3674   gs://cmip6/CMIP/CCCma/CanESM5/historical/r5i1p...             NaN
# 3731   gs://cmip6/CMIP/CCCma/CanESM5/historical/r5i1p...             NaN
# 3802   gs://cmip6/CMIP/CCCma/CanESM5/historical/r6i1p...             NaN
# 3870   gs://cmip6/CMIP/CCCma/CanESM5/historical/r6i1p...             NaN
# 3941   gs://cmip6/CMIP/CCCma/CanESM5/historical/r7i1p...             NaN
# ...                                                  ...             ...
# 8877   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 8957   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 9037   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 9117   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 9197   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 9432   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r1...             NaN
# 9500   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r2...             NaN
# 9568   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r3...             NaN
# 22250  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 22326  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 22750  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 22813  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 23116  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r2...             NaN
# 23178  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r2...             NaN
# 23241  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r3...             NaN
# 23303  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r3...             NaN
# 23366  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r4...             NaN
# 23428  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r4...             NaN
# 23492  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r5...             NaN
# 23555  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r5...             NaN
# 23619  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r6...             NaN
# 23681  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r6...             NaN
# 23745  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23807  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23870  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23933  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23997  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24060  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 26101  gs://cmip6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp58...             NaN
# 26278  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
#
# [92 rows x 10 columns]

# %% [markdown]
# ### Loading data
#
# `intake-esm` enables loading data directly into an [xarray.Dataset](http://xarray.pydata.org/en/stable/api.html#dataset).
#
# Note that data on the cloud are in
# [zarr](https://zarr.readthedocs.io/en/stable/) format and data on
# [glade](https://www2.cisl.ucar.edu/resources/storage-and-file-systems/glade-file-spaces) are stored as
# [netCDF](https://www.unidata.ucar.edu/software/netcdf/) files. This is opaque to the user.
#
# `intake-esm` has rules for aggegating datasets; these rules are defined in the collection-specification file.

# %%
dset_dict = cat.to_dataset_dict(zarr_kwargs={'consolidated': True}, 
                                cdf_kwargs={'chunks': {}})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 6 group(s)

# %% [markdown]
# `dset_dict` is a dictionary of `xarray.Dataset`'s; its keys are constructed to refer to compatible groups.

# %%
dset_dict.keys()
# Out:
# dict_keys(['CMIP.CCCma.CanESM5.historical.Oyr.gn', 'CMIP.IPSL.IPSL-CM6A-LR.historical.Oyr.gn', 'CMIP.MIROC.MIROC-ES2L.historical.Oyr.gn', 'ScenarioMIP.CCCma.CanESM5.ssp585.Oyr.gn', 'ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.Oyr.gn', 'ScenarioMIP.MIROC.MIROC-ES2L.ssp585.Oyr.gn'])

# %% [markdown]
# We can access a particular dataset as follows.

# %%
dset_dict['CMIP.CCCma.CanESM5.historical.Oyr.gn']
# Out:
# <xarray.Dataset>
# Dimensions:             (bnds: 2, i: 360, j: 291, lev: 45, member_id: 35, time: 165, vertices: 4)
# Coordinates:
#   * lev                 (lev) float64 3.047 9.454 16.36 ... 5.375e+03 5.625e+03
#   * i                   (i) int32 0 1 2 3 4 5 6 ... 353 354 355 356 357 358 359
#   * j                   (j) int32 0 1 2 3 4 5 6 ... 284 285 286 287 288 289 290
#   * time                (time) object 1850-07-02 12:00:00 ... 2014-07-02 12:00:00
#   * member_id           (member_id) <U9 'r10i1p1f1' 'r10i1p2f1' ... 'r9i1p2f1'
# Dimensions without coordinates: bnds, vertices
# Data variables:
#     time_bnds           (time, bnds) object dask.array<chunksize=(165, 2), meta=np.ndarray>
#     longitude           (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     lev_bnds            (lev, bnds) float64 dask.array<chunksize=(45, 2), meta=np.ndarray>
#     latitude            (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     o2                  (member_id, time, lev, j, i) float32 dask.array<chunksize=(1, 12, 45, 291, 360), meta=np.ndarray>
# Attributes:
#     cmor_version:                3.4.0
#     creation_date:               2019-05-30T08:58:45Z
#     tracking_id:                 hdl:21.14100/41426118-701c-482b-ae16-82932e4...
#     realm:                       ocnBgchem
#     realization_index:           9
#     nominal_resolution:          100 km
#     parent_experiment_id:        piControl
#     frequency:                   yr
#     grid_label:                  gn
#     sub_experiment:              none
#     data_specs_version:          01.00.29
#     activity_id:                 CMIP
#     grid:                        ORCA1 tripolar grid, 1 deg with refinement t...
#     title:                       CanESM5 output prepared for CMIP6
#     Conventions:                 CF-1.7 CMIP-6.2
#     further_info_url:            https://furtherinfo.es-doc.org/CMIP6.CCCma.C...
#     source:                      CanESM5 (2019): \naerosol: interactive\natmo...
#     CCCma_parent_runid:          p2-pictrl
#     branch_method:               Spin-up documentation
#     source_type:                 AOGCM
#     variant_label:               r9i1p2f1
#     initialization_index:        1
#     parent_mip_era:              CMIP6
#     table_id:                    Oyr
#     mip_era:                     CMIP6
#     CCCma_model_hash:            Unknown
#     experiment_id:               historical
#     parent_source_id:            CanESM5
#     references:                  Geophysical Model Development Special issue ...
#     product:                     model-output
#     table_info:                  Creation Date:(20 February 2019) MD5:374fbe5...
#     history:                     2019-05-02T13:53:53Z ;rewrote data to be con...
#     sub_experiment_id:           none
#     institution_id:              CCCma
#     contact:                     ec.cccma.info-info.ccmac.ec@canada.ca
#     parent_time_units:           days since 1850-01-01 0:0:0.0
#     branch_time_in_child:        0.0
#     branch_time_in_parent:       1496500.0
#     parent_activity_id:          CMIP
#     external_variables:          areacello volcello
#     CCCma_runid:                 p2-his09
#     forcing_index:               1
#     institution:                 Canadian Centre for Climate Modelling and An...
#     variable_id:                 o2
#     source_id:                   CanESM5
#     experiment:                  all-forcing simulation of the recent past
#     YMDH_branch_time_in_child:   1850:01:01:00
#     YMDH_branch_time_in_parent:  5950:01:01:00
#     version:                     v20190429
#     license:                     CMIP6 model data produced by The Government ...

# %% [markdown]
# ### More advanced queries
#
# As motivation for diving into more advanced manipulations with `intake-esm`, let's consider the task of getting access to grid information in the `Ofx` table_id.

# %%
cat_fx = col.search(experiment_id=['historical', 'ssp585'], source_id=models, table_id='Ofx', grid_label='gn')
cat_fx.df
# Out:
#        activity_id institution_id     source_id experiment_id  member_id  \
# 1487          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1488          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1489          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1490          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1587          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1588          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1589          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1590          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1657          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1658          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1659          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1660          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1697          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1698          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1699          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1700          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1753          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1754          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1755          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1756          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1793          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1794          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1795          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1796          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1849          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1850          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1851          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1852          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1890          CMIP          CCCma       CanESM5    historical  r13i1p2f1
# 1891          CMIP          CCCma       CanESM5    historical  r13i1p2f1
# ...            ...            ...           ...           ...        ...
# 23676  ScenarioMIP          CCCma       CanESM5        ssp585   r6i1p2f1
# 23737  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23738  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23739  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23740  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23799  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23800  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23801  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23802  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23862  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23863  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23864  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23865  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23924  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23925  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23926  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23927  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23988  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 23989  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 23990  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 23991  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 24052  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 24053  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 24054  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 24055  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 26067  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585   r1i1p1f1
# 26068  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585   r1i1p1f1
# 26256  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
# 26257  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
# 26258  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
#
#       table_id variable_id grid_label  \
# 1487       Ofx   areacello         gn
# 1488       Ofx      deptho         gn
# 1489       Ofx       sftof         gn
# 1490       Ofx    thkcello         gn
# 1587       Ofx   areacello         gn
# 1588       Ofx      deptho         gn
# 1589       Ofx       sftof         gn
# 1590       Ofx    thkcello         gn
# 1657       Ofx   areacello         gn
# 1658       Ofx      deptho         gn
# 1659       Ofx       sftof         gn
# 1660       Ofx    thkcello         gn
# 1697       Ofx   areacello         gn
# 1698       Ofx      deptho         gn
# 1699       Ofx       sftof         gn
# 1700       Ofx    thkcello         gn
# 1753       Ofx   areacello         gn
# 1754       Ofx      deptho         gn
# 1755       Ofx       sftof         gn
# 1756       Ofx    thkcello         gn
# 1793       Ofx   areacello         gn
# 1794       Ofx      deptho         gn
# 1795       Ofx       sftof         gn
# 1796       Ofx    thkcello         gn
# 1849       Ofx   areacello         gn
# 1850       Ofx      deptho         gn
# 1851       Ofx       sftof         gn
# 1852       Ofx    thkcello         gn
# 1890       Ofx   areacello         gn
# 1891       Ofx      deptho         gn
# ...        ...         ...        ...
# 23676      Ofx    thkcello         gn
# 23737      Ofx   areacello         gn
# 23738      Ofx      deptho         gn
# 23739      Ofx       sftof         gn
# 23740      Ofx    thkcello         gn
# 23799      Ofx   areacello         gn
# 23800      Ofx      deptho         gn
# 23801      Ofx       sftof         gn
# 23802      Ofx    thkcello         gn
# 23862      Ofx   areacello         gn
# 23863      Ofx      deptho         gn
# 23864      Ofx       sftof         gn
# 23865      Ofx    thkcello         gn
# 23924      Ofx   areacello         gn
# 23925      Ofx      deptho         gn
# 23926      Ofx       sftof         gn
# 23927      Ofx    thkcello         gn
# 23988      Ofx   areacello         gn
# 23989      Ofx      deptho         gn
# 23990      Ofx       sftof         gn
# 23991      Ofx    thkcello         gn
# 24052      Ofx   areacello         gn
# 24053      Ofx      deptho         gn
# 24054      Ofx       sftof         gn
# 24055      Ofx    thkcello         gn
# 26067      Ofx   areacello         gn
# 26068      Ofx       basin         gn
# 26256      Ofx   areacello         gn
# 26257      Ofx      deptho         gn
# 26258      Ofx       sftof         gn
#
#                                                   zstore  dcpp_init_year
# 1487   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1488   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1489   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1490   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1587   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1588   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1589   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1590   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1657   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1658   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1659   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1660   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1697   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1698   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1699   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1700   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1753   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1754   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1755   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1756   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1793   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1794   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1795   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1796   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1849   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1850   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1851   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1852   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1890   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1891   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# ...                                                  ...             ...
# 23676  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r6...             NaN
# 23737  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23738  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23739  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23740  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23799  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23800  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23801  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23802  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23862  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23863  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23864  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23865  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23924  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23925  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23926  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23927  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23988  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 23989  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 23990  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 23991  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24052  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24053  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24054  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24055  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 26067  gs://cmip6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp58...             NaN
# 26068  gs://cmip6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp58...             NaN
# 26256  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
# 26257  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
# 26258  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
#
# [418 rows x 10 columns]

# %% [markdown]
# This, however, comes with lots of redundant information.
#
# Additionally, it may be necessary to do more targeted manipulations of the search. For instance, we've found a handful of corrupted files on `glade` and might need to work around loading these.
#
# As an illustration of this, in the code below, we specify a list of to queries (in this case one) to eliminate.

# %%
import numpy as np

# specify a list of queries to eliminate
corrupt_data = [dict(variable_id='areacello', source_id='IPSL-CM6A-LR',
                     experiment_id='historical', member_id='r2i1p1f1')
               ]


# copy the dataframe 
df = cat_fx.df.copy()

# eliminate data
for elim in corrupt_data:
    condition = np.ones(len(df), dtype=bool)
    for key, val in elim.items():
        condition = condition & (df[key] == val)
    df = df.loc[~condition]
df
# Out:
#        activity_id institution_id     source_id experiment_id  member_id  \
# 1487          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1488          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1489          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1490          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1587          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1588          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1589          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1590          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1657          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1658          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1659          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1660          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1697          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1698          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1699          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1700          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1753          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1754          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1755          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1756          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1793          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1794          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1795          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1796          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1849          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1850          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1851          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1852          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1890          CMIP          CCCma       CanESM5    historical  r13i1p2f1
# 1891          CMIP          CCCma       CanESM5    historical  r13i1p2f1
# ...            ...            ...           ...           ...        ...
# 23676  ScenarioMIP          CCCma       CanESM5        ssp585   r6i1p2f1
# 23737  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23738  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23739  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23740  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23799  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23800  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23801  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23802  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23862  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23863  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23864  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23865  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23924  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23925  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23926  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23927  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23988  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 23989  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 23990  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 23991  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 24052  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 24053  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 24054  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 24055  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 26067  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585   r1i1p1f1
# 26068  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585   r1i1p1f1
# 26256  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
# 26257  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
# 26258  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
#
#       table_id variable_id grid_label  \
# 1487       Ofx   areacello         gn
# 1488       Ofx      deptho         gn
# 1489       Ofx       sftof         gn
# 1490       Ofx    thkcello         gn
# 1587       Ofx   areacello         gn
# 1588       Ofx      deptho         gn
# 1589       Ofx       sftof         gn
# 1590       Ofx    thkcello         gn
# 1657       Ofx   areacello         gn
# 1658       Ofx      deptho         gn
# 1659       Ofx       sftof         gn
# 1660       Ofx    thkcello         gn
# 1697       Ofx   areacello         gn
# 1698       Ofx      deptho         gn
# 1699       Ofx       sftof         gn
# 1700       Ofx    thkcello         gn
# 1753       Ofx   areacello         gn
# 1754       Ofx      deptho         gn
# 1755       Ofx       sftof         gn
# 1756       Ofx    thkcello         gn
# 1793       Ofx   areacello         gn
# 1794       Ofx      deptho         gn
# 1795       Ofx       sftof         gn
# 1796       Ofx    thkcello         gn
# 1849       Ofx   areacello         gn
# 1850       Ofx      deptho         gn
# 1851       Ofx       sftof         gn
# 1852       Ofx    thkcello         gn
# 1890       Ofx   areacello         gn
# 1891       Ofx      deptho         gn
# ...        ...         ...        ...
# 23676      Ofx    thkcello         gn
# 23737      Ofx   areacello         gn
# 23738      Ofx      deptho         gn
# 23739      Ofx       sftof         gn
# 23740      Ofx    thkcello         gn
# 23799      Ofx   areacello         gn
# 23800      Ofx      deptho         gn
# 23801      Ofx       sftof         gn
# 23802      Ofx    thkcello         gn
# 23862      Ofx   areacello         gn
# 23863      Ofx      deptho         gn
# 23864      Ofx       sftof         gn
# 23865      Ofx    thkcello         gn
# 23924      Ofx   areacello         gn
# 23925      Ofx      deptho         gn
# 23926      Ofx       sftof         gn
# 23927      Ofx    thkcello         gn
# 23988      Ofx   areacello         gn
# 23989      Ofx      deptho         gn
# 23990      Ofx       sftof         gn
# 23991      Ofx    thkcello         gn
# 24052      Ofx   areacello         gn
# 24053      Ofx      deptho         gn
# 24054      Ofx       sftof         gn
# 24055      Ofx    thkcello         gn
# 26067      Ofx   areacello         gn
# 26068      Ofx       basin         gn
# 26256      Ofx   areacello         gn
# 26257      Ofx      deptho         gn
# 26258      Ofx       sftof         gn
#
#                                                   zstore  dcpp_init_year
# 1487   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1488   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1489   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1490   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1587   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1588   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1589   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1590   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1657   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1658   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1659   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1660   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1697   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1698   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1699   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1700   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1753   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1754   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1755   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1756   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1793   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1794   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1795   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1796   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1849   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1850   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1851   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1852   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1890   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1891   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# ...                                                  ...             ...
# 23676  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r6...             NaN
# 23737  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23738  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23739  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23740  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23799  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23800  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23801  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23802  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23862  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23863  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23864  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23865  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23924  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23925  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23926  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23927  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23988  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 23989  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 23990  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 23991  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24052  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24053  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24054  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24055  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 26067  gs://cmip6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp58...             NaN
# 26068  gs://cmip6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp58...             NaN
# 26256  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
# 26257  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
# 26258  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
#
# [417 rows x 10 columns]

# %% [markdown]
# We then drop duplicates.

# %%
df.drop_duplicates(subset=['source_id', 'variable_id'], inplace=True)

# %% [markdown]
# Now, since we've only retained one ensemble member, we need to eliminate that column. If we omit this step, `intake-esm` will throw an error, complaining that different variables are present for each ensemble member. Setting the `member_id` column to NaN precludes attempts to join along the ensemble dimension.
#
# After this final manipulation, we copy the `DataFrame` back to the collection object and proceed with loading the data.

# %%
df['member_id'] = np.nan
cat_fx.df = df

# %%
fx_dsets = cat_fx.to_dataset_dict(zarr_kwargs={'consolidated': True}, cdf_kwargs={'chunks': {}})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 3 group(s)

# %%
fx_dsets.keys()
# Out:
# dict_keys(['CMIP.CCCma.CanESM5.historical.Ofx.gn', 'CMIP.IPSL.IPSL-CM6A-LR.historical.Ofx.gn', 'CMIP.MIROC.MIROC-ES2L.historical.Ofx.gn'])

# %%
for key, ds in fx_dsets.items():
    print(ds.data_vars)
# Out:
# Data variables:
#     areacello           (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     latitude            (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     longitude           (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     deptho              (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     sftof               (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     type                |S3 ...
#     lev_bnds            (lev, bnds) float64 dask.array<chunksize=(45, 2), meta=np.ndarray>
#     thkcello            (lev, j, i) float32 dask.array<chunksize=(45, 291, 360), meta=np.ndarray>
# Data variables:
#     area            (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     areacello       (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     bounds_nav_lat  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     bounds_nav_lon  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     nav_lat         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     nav_lon         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     basin           (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
# Data variables:
#     areacello           (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     latitude            (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     longitude           (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     vertices_latitude   (y, x, vertices) float32 dask.array<chunksize=(256, 360, 4), meta=np.ndarray>
#     vertices_longitude  (y, x, vertices) float32 dask.array<chunksize=(256, 360, 4), meta=np.ndarray>
#     x_bnds              (x, bnds) float64 dask.array<chunksize=(360, 2), meta=np.ndarray>
#     y_bnds              (y, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#     deptho              (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     sftof               (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     type                |S3 ...

# %% [markdown]
# ## Demonstrate how spin-up a dask cluster
#
# If you expect to require Big Data capabilities, here's how you spin up a [dask](https://dask.org) cluster using [dask-jobqueue](https://dask-jobqueue.readthedocs.io/en/latest/).
#
# The syntax is different if on an NCAR machine versus the cloud.

# %%
if util.is_ncar_host():
    from ncar_jobqueue import NCARCluster
    cluster = NCARCluster(project='UCGD0006')
    cluster.adapt(minimum_jobs=1, maximum_jobs=10)
else:
    from dask_kubernetes import KubeCluster
    cluster = KubeCluster()
    cluster.adapt(minimum=1, maximum=10)
cluster
# Out:
# VBox(children=(HTML(value='<h2>KubeCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    .…

# %%
from dask.distributed import Client
client = Client(cluster) # Connect this local process to remote workers
client
# Out:
# <Client: 'tcp://10.32.78.134:45953' processes=0 threads=0, memory=0 B>
